# %%
import pandas as pd

# %%
data=pd.read_csv('./titanic.csv')

# %%
data
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ### Group by

# %%
sex_survived=data.groupby(['Sex'])['Survived'].sum()

# %%
sex_survived
# Out:
# Sex
# female    233.0
# male      109.0
# Name: Survived, dtype: float64

# %%
Pclass_Survived=data.groupby(['Pclass'])['Survived'].sum()

# %%
Pclass_Survived
# Out:
# Pclass
# 1    136.0
# 2     87.0
# 3    119.0
# Name: Survived, dtype: float64

# %% [markdown]
# ### query

# %% [markdown]
# ### Boarded from Southampton

# %%
Boarded_Southampton=data.query('Boarded=="Southampton"')

# %%
Boarded_Southampton
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# 6               7       0.0       1
# ...           ...       ...     ...
# 1302         1303       NaN       1
# 1303         1304       NaN       3
# 1304         1305       NaN       3
# 1306         1307       NaN       3
# 1307         1308       NaN       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %% [markdown]
# ### Boarded from Cherbourg

# %%
Boarded_Cherbourg=data.query('Boarded=="Cherbourg"')

# %%
Boarded_Cherbourg
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2       1.0       1
# 9              10       1.0       2
# 19             20       1.0       3
# 26             27       0.0       3
# 30             31       0.0       1
# ...           ...       ...     ...
# 1288         1289       NaN       1
# 1293         1294       NaN       1
# 1296         1297       NaN       2
# 1305         1306       NaN       1
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                   Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                              Masselmani, Mrs. Fatima  female   NaN      0
# 26                              Emir, Mr. Farred Chehab    male   NaN      0
# 30                             Uruchurtu, Don. Manuel E    male  40.0      0
# ...

# %% [markdown]
# ### Gender Males

# %%
Sex_male=data.query('Sex=="male"')
Sex_male
# Out:
#       PassengerId  Survived  Pclass                            Name   Sex  \
# 0               1       0.0       3         Braund, Mr. Owen Harris  male
# 4               5       0.0       3        Allen, Mr. William Henry  male
# 5               6       0.0       3                Moran, Mr. James  male
# 6               7       0.0       1         McCarthy, Mr. Timothy J  male
# 7               8       0.0       3  Palsson, Master. Gosta Leonard  male
# ...           ...       ...     ...                             ...   ...
# 1298         1299       NaN       1      Widener, Mr. George Dunton  male
# 1304         1305       NaN       3              Spector, Mr. Woolf  male
# 1306         1307       NaN       3    Saether, Mr. Simon Sivertsen  male
# 1307         1308       NaN       3             Ware, Mr. Frederick  male
# 1308         1309       NaN       3        Peter, Master. Michael J  male
#
#        Age  SibSp  Parch              Ticket      Fare  ... Embarked  WikiId  \
# ...

# %% [markdown]
# ###  Females Boarded from Southampton

# %%
Boarded_Southampton=data.query('Boarded=="Southampton" & Sex=="female"')

# %%
Boarded_Southampton
# Out:
#       PassengerId  Survived  Pclass  \
# 2               3       1.0       3
# 3               4       1.0       1
# 8               9       1.0       3
# 10             11       1.0       3
# 11             12       1.0       1
# ...           ...       ...     ...
# 1276         1277       NaN       2
# 1291         1292       NaN       1
# 1300         1301       NaN       3
# 1302         1303       NaN       1
# 1303         1304       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                      Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                             Bonnell, Miss. Elizabeth  female  58.0      0
# ...

# %% [markdown]
# ### Survived males in pclass1 above 25age

# %%
Pclass_survived=data.query('Pclass==1&Sex=="male"&Age>25')

# %%
Pclass_survived
# Out:
#       PassengerId  Survived  Pclass                            Name   Sex  \
# 6               7       0.0       1         McCarthy, Mr. Timothy J  male
# 23             24       1.0       1    Sloper, Mr. William Thompson  male
# 30             31       0.0       1        Uruchurtu, Don. Manuel E  male
# 34             35       0.0       1         Meyer, Mr. Edgar Joseph  male
# 35             36       0.0       1  Holverson, Mr. Alexander Oskar  male
# ...           ...       ...     ...                             ...   ...
# 1246         1247       NaN       1        Julian, Mr. Henry Forbes  male
# 1263         1264       NaN       1         Ismay, Mr. Joseph Bruce  male
# 1269         1270       NaN       1     Hipkins, Mr. William Edward  male
# 1295         1296       NaN       1    Frauenthal, Mr. Isaac Gerald  male
# 1298         1299       NaN       1      Widener, Mr. George Dunton  male
#
#        Age  SibSp  Parch    Ticket      Fare  ... Embarked WikiId  \
# ...
